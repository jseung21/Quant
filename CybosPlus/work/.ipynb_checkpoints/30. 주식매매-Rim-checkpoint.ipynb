# %% [markdown]
# ### 처리
# 1. 파라미터 설정
# 1. 매수 후보 종목 선별
# 1. 포트폴리오 조회 및 잔액갱신
# 1. 당일 스코아 계산
# 2. 매도 종목 검색
# 4. 매수 종목 선정
# 1. (날짜 다음날 전환)
# 1. 매도처리
# 5. 매수처리

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob
import os
import sqlite3
import csv
import random
import sqlalchemy

from sqlalchemy import create_engine

# %matplotlib notebook

# %%
# 전일영업일자 계산
def getBeforeWorkingDate(today):
    sql = "SELECT date FROM holiday_calendar WHERE date < {} AND holiday = 0".format(today)
    return pd.read_sql(sql, engine, index_col=None).max()['date']

# 
def checkHoliday(day):
    sql = "SELECT holiday FROM holiday_calendar WHERE date = {}".format(day)
    return pd.read_sql(sql, engine, index_col=None)['holiday'][0]

# %%
# *****************************
# 파라미터 설정
# *****************************
# 시작날짜
today = "20160105"
# 종료날짜
END_DAY = "20100106"
# 선별거래종목수
CANDIDATE_STOCK_CNT = 10
# 매수/매도 거래량
AMOUNT_BUY = 10
AMOUNT_SELL = 10
# 거래 주기 일자
CYCLE_DAY = 1

# directory
WORKING_DIR = "../data"
# db file
# dbDir = 'C:/Users/jseung21/Documents/CybosPlus/sqlite3'

# %%
# DBCP
engine = create_engine("postgresql://monday:monday1!@34.97.231.194:5432/quants") # set yours

# %% [markdown]
# ### Loop 시작점

# %%
# 날짜 설정
# today = START_DAY
beforeDay = getBeforeWorkingDate(today)
print("today:[{}], beforDay:[{}]".format(today,beforeDay))
# Out:
# today:[20160105], beforDay:[20160104]

# %%
# *****************************
# 매수 후보 종목 선별 TODO 지연
# *****************************

# kospi 200 종목 검색
dfKospi200 = pd.read_sql("SELECT * FROM kospi200", engine, index_col=None)
    
### kospi200 종목중에서 매수 후보 주식 선별
i = 0
j = 0
candidate = []
for stockCode in dfKospi200['stockCode']:
    # 
    sqlTdoay = "SELECT \"stockCode\" FROM origin_trade WHERE 1=1 \
                AND \"stockCode\" = '{}' \
                AND \"date\" = {} \
                AND \"days5MovAvr\" > \"days20MovAvr\"" \
                .format(stockCode,today)
    sqlBeforeDay = "SELECT \"stockCode\" FROM origin_trade WHERE 1=1 \
                AND \"stockCode\" = '{}' \
                AND \"date\" = {} \
                AND \"days5MovAvr\" <= \"days20MovAvr\"" \
                .format(stockCode,beforeDay)
    
    result1 = pd.read_sql(sqlTdoay, engine, index_col=None)
    
    if len(result1) != 0:
        result2 = pd.read_sql(sqlBeforeDay, engine, index_col=None)
        
        if len(result2) != 0:
            j += 1
            candidate.append(result2['stockCode'][0])
        
    i += 1
    print("[{}]번째 진행중, [{}]데이터 보유".format(i,j))
    
print("candidate : [{}]".format(len(candidate)))

# 매수 후보 종목 csv 파일생성
fileName = "{}/candidate_{}.csv".format(WORKING_DIR, today)
with open(fileName, 'w') as csvFile:
    writer = csv.writer(csvFile)
    writer.writerow(candidate)

csvFile.close()
# Out:
# [1]번째 진행중, [0]데이터 보유
# [2]번째 진행중, [0]데이터 보유
# [3]번째 진행중, [0]데이터 보유
# [4]번째 진행중, [0]데이터 보유
# [5]번째 진행중, [0]데이터 보유
# [6]번째 진행중, [0]데이터 보유
# [7]번째 진행중, [0]데이터 보유
# [8]번째 진행중, [0]데이터 보유
# [9]번째 진행중, [1]데이터 보유
# [10]번째 진행중, [1]데이터 보유
# [11]번째 진행중, [1]데이터 보유
# [12]번째 진행중, [1]데이터 보유
# [13]번째 진행중, [1]데이터 보유
# [14]번째 진행중, [1]데이터 보유
# [15]번째 진행중, [1]데이터 보유
# [16]번째 진행중, [1]데이터 보유
# [17]번째 진행중, [1]데이터 보유
# [18]번째 진행중, [1]데이터 보유
# [19]번째 진행중, [1]데이터 보유
# [20]번째 진행중, [1]데이터 보유
# [21]번째 진행중, [1]데이터 보유
# [22]번째 진행중, [1]데이터 보유
# [23]번째 진행중, [1]데이터 보유
# [24]번째 진행중, [1]데이터 보유
# [25]번째 진행중, [1]데이터 보유
# [26]번째 진행중, [1]데이터 보유
# [27]번째 진행중, [1]데이터 보유
# [28]번째 진행중, [1]데이터 보유
# [29]번째 진행중, [1]데이터 보유
# [30]번째 진행중, [1]데이터 보유
# [31]번째 진행중, [2]데이터 보유
# [32]번째 진행중, [2]데이터 보유
# [33]번째 진행중, [2]데이터 보유
# [34]번째 진행중, [2]데이터 보유
# [35]번째 진행중, [2]데이터 보유
# [36]번째 진행중, [2]데이터 보유
# [37]번째 진행중, [2]데이터 보유
# [38]번째 진행중, [2]데이터 보유
# [39]번째 진행중, [2]데이터 보유
# [40]번째 진행중, [2]데이터 보유
# [41]번째 진행중, [2]데이터 보유
# [42]번째 진행중, [2]데이터 보유
# [43]번째 진행중, [2]데이터 보유
# [44]번째 진행중, [2]데이터 보유
# [45]번째 진행중, [2]데이터 보유
# [46]번째 진행중, [2]데이터 보유
# [47]번째 진행중, [2]데이터 보유
# [48]번째 진행중, [2]데이터 보유
# [49]번째 진행중, [2]데이터 보유
# [50]번째 진행중, [2]데이터 보유
# [51]번째 진행중, [2]데이터 보유
# [52]번째 진행중, [2]데이터 보유
# [53]번째 진행중, [2]데이터 보유
# [54]번째 진행중, [2]데이터 보유
# [55]번째 진행중, [2]데이터 보유
# [56]번째 진행중, [2]데이터 보유
# [57]번째 진행중, [2]데이터 보유
# [58]번째 진행중, [2]데이터 보유
# [59]번째 진행중, [2]데이터 보유
# [60]번째 진행중, [2]데이터 보유
# [61]번째 진행중, [2]데이터 보유
# [62]번째 진행중, [2]데이터 보유
# [63]번째 진행중, [2]데이터 보유
# [64]번째 진행중, [2]데이터 보유
# [65]번째 진행중, [2]데이터 보유
# [66]번째 진행중, [2]데이터 보유
# [67]번째 진행중, [2]데이터 보유
# [68]번째 진행중, [2]데이터 보유
# [69]번째 진행중, [2]데이터 보유
# [70]번째 진행중, [2]데이터 보유
# [71]번째 진행중, [2]데이터 보유
# [72]번째 진행중, [2]데이터 보유
# [73]번째 진행중, [2]데이터 보유
# [74]번째 진행중, [2]데이터 보유
# [75]번째 진행중, [2]데이터 보유
# [76]번째 진행중, [2]데이터 보유
# [77]번째 진행중, [2]데이터 보유
# [78]번째 진행중, [2]데이터 보유
# [79]번째 진행중, [2]데이터 보유
# [80]번째 진행중, [2]데이터 보유
# [81]번째 진행중, [2]데이터 보유
# [82]번째 진행중, [3]데이터 보유
# [83]번째 진행중, [3]데이터 보유
# [84]번째 진행중, [3]데이터 보유
# [85]번째 진행중, [3]데이터 보유
# [86]번째 진행중, [3]데이터 보유
# [87]번째 진행중, [3]데이터 보유
# [88]번째 진행중, [3]데이터 보유
# [89]번째 진행중, [3]데이터 보유
# [90]번째 진행중, [3]데이터 보유
# [91]번째 진행중, [3]데이터 보유
# [92]번째 진행중, [3]데이터 보유
# [93]번째 진행중, [3]데이터 보유
# [94]번째 진행중, [3]데이터 보유
# [95]번째 진행중, [3]데이터 보유
# [96]번째 진행중, [3]데이터 보유
# [97]번째 진행중, [3]데이터 보유
# [98]번째 진행중, [3]데이터 보유
# [99]번째 진행중, [3]데이터 보유
# [100]번째 진행중, [3]데이터 보유
# [101]번째 진행중, [4]데이터 보유
# [102]번째 진행중, [4]데이터 보유
# [103]번째 진행중, [4]데이터 보유
# [104]번째 진행중, [4]데이터 보유
# [105]번째 진행중, [4]데이터 보유
# [106]번째 진행중, [4]데이터 보유
# [107]번째 진행중, [4]데이터 보유
# [108]번째 진행중, [4]데이터 보유
# [109]번째 진행중, [4]데이터 보유
# [110]번째 진행중, [4]데이터 보유
# [111]번째 진행중, [4]데이터 보유
# [112]번째 진행중, [4]데이터 보유
# [113]번째 진행중, [4]데이터 보유
# [114]번째 진행중, [4]데이터 보유
# [115]번째 진행중, [4]데이터 보유
# [116]번째 진행중, [4]데이터 보유
# [117]번째 진행중, [4]데이터 보유
# [118]번째 진행중, [4]데이터 보유
# [119]번째 진행중, [4]데이터 보유
# [120]번째 진행중, [4]데이터 보유
# [121]번째 진행중, [4]데이터 보유
# [122]번째 진행중, [4]데이터 보유
# [123]번째 진행중, [4]데이터 보유
# [124]번째 진행중, [4]데이터 보유
# [125]번째 진행중, [4]데이터 보유
# [126]번째 진행중, [4]데이터 보유
# [127]번째 진행중, [4]데이터 보유
# [128]번째 진행중, [4]데이터 보유
# [129]번째 진행중, [4]데이터 보유
# [130]번째 진행중, [4]데이터 보유
# [131]번째 진행중, [4]데이터 보유
# [132]번째 진행중, [4]데이터 보유
# [133]번째 진행중, [4]데이터 보유
# [134]번째 진행중, [4]데이터 보유
# [135]번째 진행중, [4]데이터 보유
# [136]번째 진행중, [5]데이터 보유
# [137]번째 진행중, [5]데이터 보유
# [138]번째 진행중, [5]데이터 보유
# [139]번째 진행중, [5]데이터 보유
# [140]번째 진행중, [5]데이터 보유
# [141]번째 진행중, [5]데이터 보유
# [142]번째 진행중, [5]데이터 보유
# [143]번째 진행중, [5]데이터 보유
# [144]번째 진행중, [5]데이터 보유
# [145]번째 진행중, [5]데이터 보유
# [146]번째 진행중, [5]데이터 보유
# [147]번째 진행중, [5]데이터 보유
# [148]번째 진행중, [5]데이터 보유
# [149]번째 진행중, [5]데이터 보유
# [150]번째 진행중, [5]데이터 보유
# [151]번째 진행중, [5]데이터 보유
# [152]번째 진행중, [5]데이터 보유
# [153]번째 진행중, [5]데이터 보유
# [154]번째 진행중, [5]데이터 보유
# [155]번째 진행중, [5]데이터 보유
# [156]번째 진행중, [5]데이터 보유
# [157]번째 진행중, [5]데이터 보유
# [158]번째 진행중, [5]데이터 보유
# [159]번째 진행중, [5]데이터 보유
# [160]번째 진행중, [5]데이터 보유
# [161]번째 진행중, [5]데이터 보유
# [162]번째 진행중, [5]데이터 보유
# [163]번째 진행중, [5]데이터 보유
# [164]번째 진행중, [5]데이터 보유
# [165]번째 진행중, [5]데이터 보유
# [166]번째 진행중, [5]데이터 보유
# [167]번째 진행중, [6]데이터 보유
# [168]번째 진행중, [6]데이터 보유
# [169]번째 진행중, [6]데이터 보유
# [170]번째 진행중, [6]데이터 보유
# [171]번째 진행중, [6]데이터 보유
# [172]번째 진행중, [6]데이터 보유
# [173]번째 진행중, [6]데이터 보유
# [174]번째 진행중, [6]데이터 보유
# [175]번째 진행중, [6]데이터 보유
# [176]번째 진행중, [6]데이터 보유
# [177]번째 진행중, [6]데이터 보유
# [178]번째 진행중, [6]데이터 보유
# [179]번째 진행중, [6]데이터 보유
# [180]번째 진행중, [6]데이터 보유
# [181]번째 진행중, [6]데이터 보유
# [182]번째 진행중, [6]데이터 보유
# [183]번째 진행중, [6]데이터 보유
# [184]번째 진행중, [6]데이터 보유
# [185]번째 진행중, [6]데이터 보유
# [186]번째 진행중, [6]데이터 보유
# [187]번째 진행중, [6]데이터 보유
# [188]번째 진행중, [6]데이터 보유
# [189]번째 진행중, [6]데이터 보유
# [190]번째 진행중, [6]데이터 보유
# [191]번째 진행중, [6]데이터 보유
# [192]번째 진행중, [6]데이터 보유
# [193]번째 진행중, [6]데이터 보유
# [194]번째 진행중, [6]데이터 보유
# [195]번째 진행중, [6]데이터 보유
# [196]번째 진행중, [6]데이터 보유
# [197]번째 진행중, [6]데이터 보유
# [198]번째 진행중, [6]데이터 보유
# [199]번째 진행중, [6]데이터 보유
# [200]번째 진행중, [6]데이터 보유
# candidate : [6]

# %%
# *****************************
# [임시] candidate list 생성
# *****************************
fileName = "{}/candidate_20160105.csv".format(WORKING_DIR)
with open(fileName) as f:
    candidate = f.read().splitlines()

print(type(candidate), len(candidate))
candidate[:5]
# Out:
# <class 'list'> 1
# ['A001060,A006280,A008930,A027410,A069620,A035720']

# %%
# *****************************
# 포트폴리오 조회 및 잔액갱신
# *****************************
sqlPortfolio = "SELECT seq, stockCode, amountBuy, priceBuy FROM portfolio WHERE 1=1 \
                AND trading = 1"
portfolio = pd.read_sql(sqlPortfolio, engine, index_col=None)

print("portfolio 건수 : [{}] ".format(len(portfolio)))

# 잔액 갱신 
for index, myStock in portfolio.iterrows():
    sqlFinalPrice = "select \"stockCode\", finalPrice from origin_trade where 1=1 \
                    and \"stockCode\" = '{}' \
                    and date = {}" \
                    .format(myStock['stockCode'], today)
#     print("sqlFinalPrice:[{}]".format(sqlFinalPrice))
    result = pd.read_sql(sqlFinalPrice, engine, index_col=None)

    # update
    priceSell = result['finalPrice'][0]*AMOUNT_SELL
    balance = priceSell - myStock['priceBuy']
    sqlUpdate = "update portfolio set \
                dateSell = {} \
                , amountSell = {} \
                , priceSell = {} \
                , balance = {} \
                where 1=1 \
                  and seq = {}" \
                .format(today, AMOUNT_SELL, priceSell, balance, myStock['seq'])
    print("sqlUpdate:[{}]".format(sqlUpdate))
    engine.execute(sqlUpdate)
# con.commit()
# Out:
# portfolio 건수 : [0]

# %%
# *****************************
# 당일 스코아 계산
# *****************************
sqlScore = "select sum(priceBuy) as totalInvest, sum(priceSell) as toltalCurrVal from portfolio"
resultScore = pd.read_sql(sqlScore, engine, index_col=None)
if resultScore['totalinvest'][0] != None:
    totalInvest = resultScore['totalInvest'][0]
    toltalCurrVal = resultScore['toltalCurrVal'][0]
    score = round(float(toltalCurrVal) / float(totalInvest),5)

    sqlIstScore = "insert into Score values ({},{}, {},{})" \
                  .format(today, totalInvest, toltalCurrVal, score)
    print("sqlIstScore:[{}]".format(sqlIstScore))
    engine.execute(sqlIstScore)
#     con.commit()

# %%
# *****************************
# 매도 종목 검색
# *****************************
stockSell = []
if len(portfolio) != 0:
    for index, stcokSell in portfolio.iterrows():
        sqlStockSell = "SELECT stockCode FROM origin_trade WHERE 1=1 \
                        AND stockCode = '{}' \
                        AND date = {} \
                        AND days5MovAvr < days20MovAvr" \
                        .format(stcokSell['stockCode'], today)
#         print("sqlStockSell:[{}]".format(sqlStockSell))
        sellStockCode = pd.read_sql(sqlStockSell, engine, index_col=None)
        
        if len(sellStockCode) != 0:
            stockSell.append([stcokSell['seq'], sellStockCode['stockCode'][0], stcokSell['priceBuy']])
            
print("stockSell 건수:[{}]".format(len(stockSell)))
# Out:
# stockSell 건수:[0]

# %%
# *****************************
# 매수 종목 선정
# *****************************
buyStockCount = CANDIDATE_STOCK_CNT - len(portfolio) + len(stockSell)
print("buyStockCount : [{}]".format(buyStockCount))

# list에서 random 추출
buyStocks = 0
if len(candidate) <= buyStockCount:
    buyStocks = candidate
else:
    buyStocks = random.sample(candidate, buyStockCount)
# Out:
# buyStockCount : [10]

# %%
# *****************************
# (날짜 다음날 전환)
# *****************************
from datetime import datetime  
from datetime import timedelta 

temp = today
for i in range(1,100):
    nextDate = datetime.strptime(str(today), "%Y%m%d") + timedelta(days=i)
    checkDay = nextDate.strftime('%Y%m%d')
    if checkHoliday(checkDay) == 0:
        break
today = checkDay
print("chage today [{}] to [{}]".format(temp, today))
# Out:
# chage today [20160105] to [20160106]

# %%
# *****************************
# 매도 처리
# *****************************
if len(stockSell) != 0:
    for sellStockCode in stockSell:
        # 시초가 거래
        sqlSell = "select startPrice from origin_trade where 1=1 \
                    AND stockCode = '{}' \
                    AND date = {}" \
                    .format(sellStockCode[1], today)
        print("sqlSell:[{}]".format(sqlSell))
        startPrice = pd.read_sql(sqlSell, engine, index_col=None)['startPrice'][0]
        
        # Trading 매도 내역 생성
        stockPrice = startPrice*AMOUNT_SELL
        sqlInstSellTrd = "insert into Trading values ({},{},'{}',{},{})" \
                        .format(today, 2, sellStockCode[1], AMOUNT_SELL, stockPrice)
        print("sqlInstSellTrd:[{}]".format(sqlInstSellTrd))
        engine.execute(sqlInstSellTrd)

        # Portfolio 갱신
        balance = stockPrice - sellStockCode[2]
        seq = sellStockCode[0]
        sqlUpdate = "update portfolio set \
                    trading = 2 \
                    , dateSell = {} \
                    , amountSell = {} \
                    , priceSell = {} \
                    , balance = {} \
                    where 1=1 \
                      and seq = {}" \
                    .format(today, AMOUNT_SELL, stockPrice, balance, seq)
        print("sqlUpdate:[{}]".format(sqlUpdate))
        engine.execute(sqlUpdate)

#     con.commit()

# %%
# *****************************
# 매수처리
# *****************************
for stockBuyCode in buyStocks:
    # 시초가 거래
    sqlBuy = "select \"startprice\" from origin_trade where 1=1 \
              AND \"stockCode\" = '{}' \
              AND date = {}" \
              .format(stockBuyCode, today)
    print("sqlBuy:[{}]".format(sqlBuy))
    startPrice = pd.read_sql(sqlBuy, engine, index_col=None)['startprice'][0]

    
    # Trading 매수 내역 생성
    sqlInstBuyTrd = "insert into trading values({},{},'{}',{},{})" \
                   .format(today, 1, stockBuyCode, AMOUNT_BUY, startPrice*AMOUNT_BUY)
    engine.execute(sqlInstBuyTrd)
    
    # Portfolio 생성
    sqlSeq = "select max(seq) as maxSeq from portfolio"
    seq = pd.read_sql(sqlSeq, engine, index_col=None)['maxSeq'][0]
    if seq == None:
        seq = 0
    seq += 1
    trading = 1
    stockPrice = startPrice*AMOUNT_BUY
    
    sqlInsert = "insert into Portfolio values({},{},'{}',{},{},{},{},{},{},{})" \
                .format(seq, trading, stockBuyCode, today, AMOUNT_BUY, stockPrice,0,0,0,0)
    print("sqlInsert:[{}]".format(sqlInsert))
    engine.execute(sqlInsert)

# con.commit()
# Out:
# sqlBuy:[select startprice from origin_trade where 1=1               AND "stockCode" = 'A001060,A006280,A008930,A027410,A069620,A035720'               AND date = 20160106]
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1245                     self.dialect.do_execute(
# -> 1246                         cursor, statement, parameters, context
#    1247                     )
#
# /usr/local/lib/python3.5/dist-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     580     def do_execute(self, cursor, statement, parameters, context=None):
# --> 581         cursor.execute(statement, parameters)
#     582
#
# UndefinedColumn: column "startprice" does not exist
# LINE 1: select startprice from origin_trade where 1=1               ...
#                ^
# HINT:  Perhaps you meant to reference the column "origin_trade.startPrice".
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-39-90212d2f32f3> in <module>
#       9               .format(stockBuyCode, today)
#      10     print("sqlBuy:[{}]".format(sqlBuy))
# ---> 11     startPrice = pd.read_sql(sqlBuy, engine, index_col=None)['startprice'][0]
#      12
#      13
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     434             coerce_float=coerce_float,
#     435             parse_dates=parse_dates,
# --> 436             chunksize=chunksize,
#     437         )
#     438
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1216         args = _convert_params(sql, params)
#    1217
# -> 1218         result = self.execute(*args)
#    1219         columns = result.keys()
#    1220
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1085     def execute(self, *args, **kwargs):
#    1086         """Simple passthrough to SQLAlchemy connectable"""
# -> 1087         return self.connectable.execute(*args, **kwargs)
#    1088
#    1089     def read_table(
#
# /usr/local/lib/python3.5/dist-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    2180
#    2181         connection = self._contextual_connect(close_with_result=True)
# -> 2182         return connection.execute(statement, *multiparams, **params)
#    2183
#    2184     def scalar(self, statement, *multiparams, **params):
#
# /usr/local/lib/python3.5/dist-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#     974         """
#     975         if isinstance(object_, util.string_types[0]):
# --> 976             return self._execute_text(object_, multiparams, params)
#     977         try:
#     978             meth = object_._execute_on_connection
#
# /usr/local/lib/python3.5/dist-packages/sqlalchemy/engine/base.py in _execute_text(self, statement, multiparams, params)
#    1147             parameters,
#    1148             statement,
# -> 1149             parameters,
#    1150         )
#    1151         if self._has_events or self.engine._has_events:
#
# /usr/local/lib/python3.5/dist-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1248         except BaseException as e:
#    1249             self._handle_dbapi_exception(
# -> 1250                 e, statement, parameters, cursor, context
#    1251             )
#    1252
#
# /usr/local/lib/python3.5/dist-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1474                 util.raise_from_cause(newraise, exc_info)
#    1475             elif should_wrap:
# -> 1476                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1477             else:
#    1478                 util.reraise(*exc_info)
#
# /usr/local/lib/python3.5/dist-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     396     exc_type, exc_value, exc_tb = exc_info
#     397     cause = exc_value if exc_value is not exception else None
# --> 398     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     399
#     400
#
# /usr/local/lib/python3.5/dist-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     150             value.__cause__ = cause
#     151         if value.__traceback__ is not tb:
# --> 152             raise value.with_traceback(tb)
#     153         raise value
#     154
#
# /usr/local/lib/python3.5/dist-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1244                 if not evt_handled:
#    1245                     self.dialect.do_execute(
# -> 1246                         cursor, statement, parameters, context
#    1247                     )
#    1248         except BaseException as e:
#
# /usr/local/lib/python3.5/dist-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     579
#     580     def do_execute(self, cursor, statement, parameters, context=None):
# --> 581         cursor.execute(statement, parameters)
#     582
#     583     def do_execute_no_params(self, cursor, statement, context=None):
#
# ProgrammingError: (psycopg2.errors.UndefinedColumn) column "startprice" does not exist
# LINE 1: select startprice from origin_trade where 1=1               ...
#                ^
# HINT:  Perhaps you meant to reference the column "origin_trade.startPrice".
#
# [SQL: select startprice from origin_trade where 1=1               AND "stockCode" = 'A001060,A006280,A008930,A027410,A069620,A035720'               AND date = 20160106]
# (Background on this error at: http://sqlalche.me/e/f405)
